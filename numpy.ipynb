# %%
import numpy as np

# %%
student_marks_arr=np.array([78,92,36,84,49])
student_marks_arr
# Out:
# array([78, 92, 36, 84, 49])

# %%
horsepower=[130,165,150,150,140]
horsepower_arr=np.array(horsepower)
horsepower_arr
# Out:
# array([130, 165, 150, 150, 140])

# %%
car_attributes=[[18,15,18,16,17],[130,165,150,150,140],[307,350,318,304,302]]
car_attributes_arr=np.array(car_attributes)
car_attributes_arr
# Out:
# array([[ 18,  15,  18,  16,  17],
#        [130, 165, 150, 150, 140],
#        [307, 350, 318, 304, 302]])

# %% [markdown]
# # shape of ndarray

# %%
car_attributes=[[18,15,18,16,17],[130,165,150,150,140],[307,350,318,304,302]]
car_attributes_arr=np.array(car_attributes)
car_attributes_arr.shape
# Out:
# (3, 5)

# %% [markdown]
# # dtype of ndarray

# %%
car_attributes=[[18,15,18,16,17],[130,165,150,150,140],[307,350,318,304,302]]
car_attributes_arr=np.array(car_attributes)
car_attributes_arr.dtype
# Out:
# dtype('int32')

# %% [markdown]
# # changing dtype

# %%
car_attributes=[[18,15,18,16,17],[130,165,150,150,140],[307,350,318,304,302]]
#converting dtype
car_attributes_arr=np.array(car_attributes,dtype="float")
print(car_attributes_arr)
print(car_attributes_arr.dtype)
# Out:
# [[ 18.  15.  18.  16.  17.]
#  [130. 165. 150. 150. 140.]
#  [307. 350. 318. 304. 302.]]
# float64

# %% [markdown]
# # Accessing elements from 1D array

# %%
#creating an arrray of cars
cars=np.array(['chevrolet chevelle malibu','buick skylark 320','plymouth satellite','amc rebel sst','ford torino'])
cars[1]
# Out:
# 'buick skylark 320'

# %% [markdown]
# # Accessing elements from 2D array

# %%
car_names=np.array(['chevrolet chevelle malibu','buick skylark 320','plymouth satellite','amc rebel sst','ford torino'])
horsepower=[130,165,150,150,140]
car_hp_arr=np.array([car_names,horsepower])
car_hp_arr
# Out:
# array([['chevrolet chevelle malibu', 'buick skylark 320',
#         'plymouth satellite', 'amc rebel sst', 'ford torino'],
#        ['130', '165', '150', '150', '140']], dtype='<U25')

# %%
car_names=np.array(['chevrolet chevelle malibu','buick skylark 320','plymouth satellite','amc rebel sst','ford torino'])
horsepower=[130,165,150,150,140]
car_hp_arr=np.array([car_names,horsepower])
car_hp_arr[0]
# Out:
# array(['chevrolet chevelle malibu', 'buick skylark 320',
#        'plymouth satellite', 'amc rebel sst', 'ford torino'], dtype='<U25')

# %%
car_names=np.array(['chevrolet chevelle malibu','buick skylark 320','plymouth satellite','amc rebel sst','ford torino'])
horsepower=[130,165,150,150,140]
car_hp_arr=np.array([car_names,horsepower])
car_hp_arr[1]
# Out:
# array(['130', '165', '150', '150', '140'], dtype='<U25')

# %%
car_names=np.array(['chevrolet chevelle malibu','buick skylark 320','plymouth satellite','amc rebel sst','ford torino'])
horsepower=[130,165,150,150,140]
car_hp_arr=np.array([car_names,horsepower])
car_hp_arr[0,1]
# Out:
# 'buick skylark 320'

# %%
car_names=np.array(['chevrolet chevelle malibu','buick skylark 320','plymouth satellite','amc rebel sst','ford torino'])
horsepower=[130,165,150,150,140]
car_hp_arr=np.array([car_names,horsepower])
car_hp_arr[0,-1]
# Out:
# 'ford torino'

# %% [markdown]
# # slicing

# %% [markdown]
# #### slicing from 1D array

# %%
cars=np.array(['chevrolet chevelle malibu','buick skylark 320','plymouth satellite','amc rebel sst','ford torino'])
cars[1:4]
# Out:
# array(['buick skylark 320', 'plymouth satellite', 'amc rebel sst'],
#       dtype='<U25')

# %% [markdown]
# #### slicing from 2D array

# %%
car_names=np.array(['chevrolet chevelle malibu','buick skylark 320','plymouth satellite','amc rebel sst','ford torino'])
horsepower=[130,165,150,150,140]
acceleration=[18,15,18,16,17]
car_hp_acc_arr=np.array([car_names,horsepower,acceleration])
car_hp_acc_arr
# Out:
# array([['chevrolet chevelle malibu', 'buick skylark 320',
#         'plymouth satellite', 'amc rebel sst', 'ford torino'],
#        ['130', '165', '150', '150', '140'],
#        ['18', '15', '18', '16', '17']], dtype='<U25')

# %%
car_names=np.array(['chevrolet chevelle malibu','buick skylark 320','plymouth satellite','amc rebel sst','ford torino'])
horsepower=[130,165,150,150,140]
acceleration=[18,15,18,16,17]
car_hp_acc_arr=np.array([car_names,horsepower,acceleration])
car_hp_acc_arr[0:2]
# Out:
# array([['chevrolet chevelle malibu', 'buick skylark 320',
#         'plymouth satellite', 'amc rebel sst', 'ford torino'],
#        ['130', '165', '150', '150', '140']], dtype='<U25')

# %%
car_names=np.array(['chevrolet chevelle malibu','buick skylark 320','plymouth satellite','amc rebel sst','ford torino'])
horsepower=[130,165,150,150,140]
acceleration=[18,15,18,16,17]
car_hp_acc_arr=np.array([car_names,horsepower,acceleration])
car_hp_acc_arr[0:2,3:5]
# Out:
# array([['amc rebel sst', 'ford torino'],
#        ['150', '140']], dtype='<U25')

# %%
car_names=np.array(['chevrolet chevelle malibu','buick skylark 320','plymouth satellite','amc rebel sst','ford torino'])
horsepower=[130,165,150,150,140]
acceleration=[18,15,18,16,17]
car_hp_acc_arr=np.array([car_names,horsepower,acceleration])
car_hp_acc_arr[0:3,0:3]
# Out:
# array([['chevrolet chevelle malibu', 'buick skylark 320',
#         'plymouth satellite'],
#        ['130', '165', '150'],
#        ['18', '15', '18']], dtype='<U25')

# %% [markdown]
# # mean and median

# %%
horsepower=[130,165,150,150,140]
horsepower_arr=np.array(horsepower)
print("mean horsepower=",np.mean(horsepower_arr))
# Out:
# mean horsepower= 147.0

# %%
horsepower=[130,165,150,150,140]
horsepower_arr=np.array(horsepower)
print("median horsepower=",np.median(horsepower_arr))
# Out:
# median horsepower= 150.0

# %% [markdown]
# # min and max

# %%
horsepower=[130,165,150,150,140]
horsepower_arr=np.array(horsepower)
print("Minimum horsepower:",np.min(horsepower_arr))
print("Maximun horsepower:",np.max(horsepower_arr))
# Out:
# Minimum horsepower: 130
# Maximun horsepower: 165

# %% [markdown]
# # Finding the index of minimum and maximum values:

# %%
horsepower=[130,165,150,150,140]
horsepower_arr=np.array(horsepower)
print("Index of minimum horsepower:",np.argmin(horsepower_arr))
print("Index of maximum horsepower:",np.argmax(horsepower_arr))
# Out:
# Index of minimum horsepower: 0
# Index of maximum horsepower: 1

# %% [markdown]
# ### Quering/Searching

# %%
horsepower=[130,165,150,150,140]
horsepower_arr=np.array(horsepower)
x=np.where(horsepower_arr>=150)
print(x)
horsepower_arr[x]
# Out:
# (array([1, 2, 3], dtype=int64),)
# array([165, 150, 150])

# %% [markdown]
# ## filter data

# %%
horsepower=[130,165,150,150,140]
horsepower_arr=np.array(horsepower)
filter_arr=horsepower_arr>135
#creating filter array
newarr=horsepower_arr[filter_arr]
print(filter_arr)
print(newarr)
# Out:
# [False  True  True  True  True]
# [165 150 150 140]

# %% [markdown]
# ### sorting array

# %%
horsepower=[130,165,150,150,140]
horsepower_arr=np.array(horsepower)
print("original array:",horsepower_arr)
print("sorted array:",np.sort(horsepower_arr))
# Out:
# original array: [130 165 150 150 140]
# sorted array: [130 140 150 150 165]

# %%
horsepower=[130,165,150,150,140]
horsepower_arr=np.array(horsepower)
#using sort(array)
horsepower_arr.sort()
print("sorted array:",horsepower_arr)
# Out:
# sorted array: [130 140 150 150 165]

# %% [markdown]
# # vectorized operations

# %%
student_marks_arr=np.array([78,92,36,84,49])
print(np.sum(student_marks_arr))
# Out:
# 339

# %%
additional_marks=[2,2,5,10,1]
student_marks_arr+=additional_marks
student_marks_arr
# Out:
# array([80, 94, 41, 94, 50])

# %%
student_marks_arr=np.array([78,92,36,84,49])
student_marks_arr=np.add(student_marks_arr,additional_marks)
student_marks_arr
# Out:
# array([80, 94, 41, 94, 50])

# %% [markdown]
# ### Broadcasting

# %%
array1=np.array([5,10,15])
array2=np.array([5])
array3=array1*array2
array3
# Out:
# array([25, 50, 75])

# %%
#students marks in 4 subjects
stmk=np.array([[67,45],[90,92],[66,72],[32,40]])
stmk
# Out:
# array([[67, 45],
#        [90, 92],
#        [66, 72],
#        [32, 40]])

# %%
#now the teacher wants to add 5 more marks
stmk=np.array([[67,45],[90,92],[66,72],[32,40]])
#broadcasting
stmk+=[5,10]
stmk
# Out:
# array([[ 72,  55],
#        [ 95, 102],
#        [ 71,  82],
#        [ 37,  50]])

# %% [markdown]
# ## importing an image

# %%
#importing paths and skimage i/o library
import os.path
from skimage.io import imread
from skimage import data_dir
#reading the astronaut image
img=imread(os.path.join(data_dir,'astronaut.png'))

# %%
#using matplotlib.pyplot to visualize the image
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
#to view as a matrix
print(img)
# Out:
# [[[154 147 151]
#   [109 103 124]
#   [ 63  58 102]
#   ...
#   [127 120 115]
#   [120 117 106]
#   [125 119 110]]
#
#  [[177 171 171]
#   [144 141 143]
#   [113 114 124]
#   ...
#   [127 118 112]
#   [124 115 108]
#   [121 116 105]]
#
#  [[201 194 193]
#   [182 178 175]
#   [168 165 164]
#   ...
#   [128 120 117]
#   [126 116 112]
#   [124 114 109]]
#
#  ...
#
#  [[186 170 176]
#   [186 170 177]
#   [183 168 170]
#   ...
#   [  0   0   0]
#   [  0   0   1]
#   [  0   0   0]]
#
#  [[183 169 170]
#   [182 167 171]
#   [185 164 176]
#   ...
#   [  0   0   1]
#   [  1   1   1]
#   [  0   0   0]]
#
#  [[184 167 172]
#   [183 165 169]
#   [180 162 171]
#   ...
#   [  0   0   0]
#   [  1   1   1]
#   [  0   0   0]]]

# %% [markdown]
# ### properties of images

# %%
print('Type of image',type(img))
print('Dimensions of image:',img.ndim)
print('shape of image:',img.shape)
# Out:
# Type of image <class 'numpy.ndarray'>
# Dimensions of image: 3
# shape of image: (512, 512, 3)

# %% [markdown]
# ### indexing and selection of image

# %%
import os.path
from skimage.io import imread
from skimage import data_dir
#reading the astronaut image
img=imread(os.path.join(data_dir,'astronaut.png'))
#slicing out the rocket
img_slice=img.copy()
img_slice=img_slice[0:300,360:480]
plt.figure()
plt.imshow(img_slice)

# %% [markdown]
# #### Assigning the values corresponding to the sliced image as 0:

# %%
img[0:300,360:480,:]=0
plt.imshow(img)

# %%
img_slice=img.copy()
img_slice=img_slice[0:300,0:340]
plt.figure()
plt.imshow(img_slice)

# %%
img_slice[np.greater_equal(img_slice[:,:,0],100)&np.less_equal(img_slice[:,:,0],150)]=0
plt.figure()
plt.imshow(img_slice)

# %%
import os.path
from skimage.io import imread
from skimage import data_dir
#reading the astronaut image
img=imread(os.path.join(data_dir,'astronaut.png'))

# %%
#using matplotlib.pyplot to visualize the image
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
import os.path
from skimage.io import imread
from skimage import data_dir
#reading the astronaut image
img=imread(os.path.join(data_dir,'astronaut.png'))
#slicing out the rocket
img_slice=img.copy()
img_slice=img_slice[0:300,360:480]
plt.figure()
plt.imshow(img_slice)

# %%
img[0:300,360:480,:]=0
plt.imshow(img)

# %%
img_slice[np.greater_equal(img_slice[:,:,0],100)&np.less_equal(img_slice[:,:,0],150)]=0
plt.figure()
plt.imshow(img_slice)

# %%
#replacing the rocket
img[0:300,360:480,:]=img_slice
plt.imshow(img)

# %% [markdown]
# #### Arange

# %%
np.arange(0,10000)
# Out:
# array([   0,    1,    2, ..., 9997, 9998, 9999])

# %%
np.arange(0,10,2)
# Out:
# array([0, 2, 4, 6, 8])

# %% [markdown]
# #### Linspace

# %%
#Generating values between 0 and 100
arr=np.linspace(0,10)
print(arr)
print('Length of arr:',len(arr))
# Out:
# [ 0.          0.20408163  0.40816327  0.6122449   0.81632653  1.02040816
#   1.2244898   1.42857143  1.63265306  1.83673469  2.04081633  2.24489796
#   2.44897959  2.65306122  2.85714286  3.06122449  3.26530612  3.46938776
#   3.67346939  3.87755102  4.08163265  4.28571429  4.48979592  4.69387755
#   4.89795918  5.10204082  5.30612245  5.51020408  5.71428571  5.91836735
#   6.12244898  6.32653061  6.53061224  6.73469388  6.93877551  7.14285714
#   7.34693878  7.55102041  7.75510204  7.95918367  8.16326531  8.36734694
#   8.57142857  8.7755102   8.97959184  9.18367347  9.3877551   9.59183673
#   9.79591837 10.        ]
# Length of arr: 50

# %%
#number of values=3
print(np.linspace(0,10,3))
# Out:
# [ 0.  5. 10.]

# %% [markdown]
# ### zeros

# %%
#1D
np.zeros(5)
# Out:
# array([0., 0., 0., 0., 0.])

# %%
#2D
np.zeros([2,3])
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %% [markdown]
# #### ones

# %%
#1D
np.ones(3)
# Out:
# array([1., 1., 1.])

# %%
#2D
np.ones([2,1])
# Out:
# array([[1.],
#        [1.]])

# %% [markdown]
# ### full:

# %%
np.full(5,8)
# Out:
# array([8, 8, 8, 8, 8])

# %%
#shape=[3,3],value=numpy
np.full([3,3],'numpy')
# Out:
# array([['numpy', 'numpy', 'numpy'],
#        ['numpy', 'numpy', 'numpy'],
#        ['numpy', 'numpy', 'numpy']], dtype='<U5')

# %% [markdown]
# ### Eye

# %% [markdown]
# #### 3x3 indentity matrix

# %%
np.eye(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %% [markdown]
# ## Random

# %%
np.random.rand(5)
# Out:
# array([0.19798693, 0.13252224, 0.10343231, 0.90522142, 0.84964694])

# %%
#random interger values low=1,high=10,number of values=5
np.random.randint(1,10,size=5)
# Out:
# array([9, 4, 4, 8, 8])

# %%
#random integer values high=100,shape=(3,5)
x=np.random.randint(100,size=(3,5))
print(x)
print(type(x))
# Out:
# [[98 90 41 21 83]
#  [46 27 33 91 91]
#  [29 23 46 34  1]]
# <class 'numpy.ndarray'>

# %% [markdown]
# ### choice()

# %%
x=np.random.choice([9,3,7,5])
print(x)
# Out:
# 9

# %%
x=np.random.choice
